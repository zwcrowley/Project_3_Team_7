# %% [markdown]
# # **Project 3- Team 7**
# ## By: Juan Marin, James Lamotte, Zack Crowley, Matusola Bein

# %% [markdown]
# #### Home Value Change and National Climate Risk Data

# %% [markdown]
# ##### Import dependencies

# %%
# Dependencies
import pandas as pd
import geopandas as gpd
import os
import numpy as np
# import json
import datetime
import pymongo
from pymongo import MongoClient, GEOSPHERE
from pymongo.errors import (PyMongoError, BulkWriteError)
import argparse, urllib
# from bson.json_util import dumps, loads 
from collections import defaultdict
from typing import Any
# from bson import ObjectId
# URLS for mongoDB cluster: 
# from mongopass import mongopass_app, mongopass_compass 
# from flask_cors import CORS
from sqlalchemy import create_engine

# %% [markdown]
# ## Import .csv Data

# %% [markdown]
# - First read in the raw .csv data from the Zillow Home Value Index ("zhvi_allhomes_ts_county.csv") and Nat'l Risk Index data ("natl_risk_index_counties.csv") into DataFrames

# %%
# Zillow Home Value Index County Time Series data:
homes_file = "resources/zhvi_allhomes_ts_county.csv"
raw_homes_df = pd.read_csv(homes_file)
raw_homes_df.head()
# Out:
#    RegionID  SizeRank          RegionName RegionType StateName State  \
# 0      3101         0  Los Angeles County     county        CA    CA
# 1       139         1         Cook County     county        IL    IL
# 2      1090         2       Harris County     county        TX    TX
# 3      2402         3     Maricopa County     county        AZ    AZ
# 4      2841         4    San Diego County     county        CA    CA
#
#                                   Metro  StateCodeFIPS  MunicipalCodeFIPS  \
# 0    Los Angeles-Long Beach-Anaheim, CA              6                 37
# 1    Chicago-Naperville-Elgin, IL-IN-WI             17                 31
# 2  Houston-The Woodlands-Sugar Land, TX             48                201
# 3             Phoenix-Mesa-Chandler, AZ              4                 13
# 4    San Diego-Chula Vista-Carlsbad, CA              6                 73
#
#    2000-01-31  ...  2022-03-31  2022-04-30  2022-05-31  2022-06-30  \
# 0    217219.0  ...    849467.0    867274.0    882623.0    884311.0
# 1    173902.0  ...    301166.0    303308.0    306745.0    309530.0
# 2    115286.0  ...    269990.0    275086.0    280076.0    283929.0
# 3    142739.0  ...    457069.0    468583.0    477443.0    483784.0
# 4    225274.0  ...    887685.0    906908.0    920069.0    919535.0
#
#    2022-07-31  2022-08-31  2022-09-30  2022-10-31  2022-11-30  2022-12-31
# 0    883805.0    870575.0    859871.0    848269.0    846262.0    845596.0
# 1    311511.0    311997.0    312558.0    313027.0    313775.0    312317.0
# 2    286477.0    288032.0    288399.0    289143.0    289720.0    289591.0
# 3    481374.0    474787.0    464870.0    459841.0    454753.0    451699.0
# 4    908231.0    897158.0    890169.0    885101.0    880975.0    874095.0
#
# [5 rows x 285 columns]

# %%
# Nat'l Risk Index County level data:
risk_file = "resources/natl_risk_index_counties.csv"
raw_risk_df = pd.read_csv(risk_file)
raw_risk_df.head()
# Out:
#    OBJECTID  NRI_ID     STATE STATEABBRV  STATEFIPS   COUNTY COUNTYTYPE  \
# 0         1  C21115  Kentucky         KY         21  Johnson     County
# 1         2  C21117  Kentucky         KY         21   Kenton     County
# 2         3  C21119  Kentucky         KY         21    Knott     County
# 3         4  C21121  Kentucky         KY         21     Knox     County
# 4         5  C21123  Kentucky         KY         21    Larue     County
#
#    COUNTYFIPS  STCOFIPS  POPULATION  ...   WNTW_EALA     WNTW_EALT  WNTW_EALS  \
# 0         115     21115       23356  ...    4.235939  47363.199731  19.448529
# 1         117     21117      159720  ...   44.606252  64259.532691  21.530408
# 2         119     21119       16346  ...    0.023091  30809.754620  16.851393
# 3         121     21121       31883  ...    0.082573  61427.308851  21.209328
# 4         123     21123       14193  ...  246.668438  12870.385216  12.597091
#
#              WNTW_EALR WNTW_RISKS           WNTW_RISKR        NRI_VER  \
# 0  Relatively Moderate  14.131237       Relatively Low  November 2021
# 1  Relatively Moderate  12.470040       Relatively Low  November 2021
# 2       Relatively Low  14.466270       Relatively Low  November 2021
# 3  Relatively Moderate  19.585915  Relatively Moderate  November 2021
# 4       Relatively Low   7.715952             Very Low  November 2021
#
#                                  GlobalID SHAPE_Length  SHAPE_Area
# 0  {55EC05F7-E576-469E-B728-EF2D3AEFD6DA}     1.553484    0.070028
# 1  {0868CDAC-FE0A-489E-8E2E-D5B7EB7AD660}     1.094178    0.044207
# 2  {A448B94E-9172-4B0C-B74B-321B3CF39E66}     1.694376    0.092941
# 3  {BA4C9D7D-5891-4EEE-9B3B-BF1F9BA5AA4A}     1.920543    0.101520
# 4  {55A74C8C-E1FD-4C88-8343-D977E94CD0B1}     1.830220    0.069616
#
# [5 rows x 368 columns]

# %% [markdown]
# ### Clean raw .csv date:
# - First, the Zillow data:

# %%
# Create a new df with cols we need from raw_homes_df:
# list(raw_homes_df.columns)
homes_df = raw_homes_df[['MunicipalCodeFIPS','StateCodeFIPS','State','RegionID', 'SizeRank', '2000-01-31','2021-12-31','2022-12-31']].copy()

# Clean up column names:
homes_df = homes_df.rename(columns={'MunicipalCodeFIPS': 'county_FIPS', 'StateCodeFIPS': 'state_FIPS', 'RegionName': 'county_name', 'State':'state_abbr','2000-01-31':'home_values_Jan_2000','2021-12-31':'home_values_Dec_2021','2022-12-31':'home_values_Dec_2022'})
homes_df.head()
# Out:
#    county_FIPS  state_FIPS state_abbr  RegionID  SizeRank  \
# 0           37           6         CA      3101         0
# 1           31          17         IL       139         1
# 2          201          48         TX      1090         2
# 3           13           4         AZ      2402         3
# 4           73           6         CA      2841         4
#
#    home_values_Jan_2000  home_values_Dec_2021  home_values_Dec_2022
# 0              217219.0              821138.0              845596.0
# 1              173902.0              294321.0              312317.0
# 2              115286.0              258440.0              289591.0
# 3              142739.0              433465.0              451699.0
# 4              225274.0              824324.0              874095.0

# %%
# Add the change in home value index from one year prior to newest data, formula from the Zillow site: 
# zhvi_yr_growth = 100 * [ ZHVI_{this month current year} – ZHVI_{this month last year} ] / [ ZHVI_{this month last year} ]
# Create the Zillow Home Value Index growth for one year from 12/21 to 12/22:

homes_df["zhvi_yr_growth"] = 100 * (homes_df["home_values_Dec_2022"] - homes_df["home_values_Dec_2021"]) / (homes_df["home_values_Dec_2021"]) 

homes_df.describe()["zhvi_yr_growth"]
# homes_df["zhvi_yr_growth"] is the percent annual growth from 12/21 to 12/22, some places saw a home value index decline so the min is negative
# Out:
# count    2784.000000
# mean       11.023814
# std         4.827320
# min       -14.695919
# 25%         7.790821
# 50%        10.465205
# 75%        13.885684
# max        44.260661
# Name: zhvi_yr_growth, dtype: float64

# %% [markdown]
# - Then, the Nat'l Risk Index data:

# %%
#  Create a new df with cols we need from raw_risk_df:
# list(raw_risk_df.columns)
risk_df = raw_risk_df[['STCOFIPS','COUNTYFIPS','COUNTY','STATE','STATEFIPS','POPULATION','BUILDVALUE','AGRIVALUE','AREA','RISK_SCORE','RISK_RATNG','EAL_SCORE','EAL_RATNG','SOVI_SCORE','SOVI_RATNG','RESL_SCORE','RESL_RATNG','CFLD_RISKS','CFLD_RISKR','DRGT_RISKS',
'DRGT_RISKR','HWAV_RISKS','HWAV_RISKR','HRCN_RISKS',
'HRCN_RISKR','LTNG_RISKS','LTNG_RISKR','RFLD_RISKS',
'RFLD_RISKR','TRND_RISKS','TRND_RISKR','WFIR_RISKS',
 'WFIR_RISKR','WNTW_RISKS','WNTW_RISKR','SHAPE_Length','SHAPE_Area']].copy()

# Clean up risk_df column names:
risk_df = risk_df.rename(columns={'STCOFIPS':'state_county_FIPS','COUNTYFIPS':'county_FIPS', 'COUNTY': 'county_name','STATE':'state','STATEFIPS':'state_FIPS','RISK_SCORE':'risk_index_score','RISK_RATNG':'risk_index_rating','EAL_SCORE':'exp_annual_loss_score','EAL_RATNG':'exp_annual_loss_rating','SOVI_SCORE':'soc_vul_score','SOVI_RATNG':'soc_vul_rating','RESL_SCORE':'comm_res_score','RESL_RATNG':'comm_res_rating','CFLD_RISKS':'coastal_flooding_score','CFLD_RISKR':'coastal_flooding_rating','DRGT_RISKS':'drought_score','DRGT_RISKR':'drought_rating','HWAV_RISKS':'heatwave_score','HWAV_RISKR':'heatwave_rating','HRCN_RISKS':'hurricane_score','HRCN_RISKR':'hurricane_rating','LTNG_RISKS':'lightning_score','LTNG_RISKR':'lightning_rating','RFLD_RISKS':'river_flooding_score','RFLD_RISKR':'river_flooding_rating','TRND_RISKS':'tornado_scores','TRND_RISKR':'tornado_rating','WFIR_RISKS':'wildfire_scores','WFIR_RISKR':'wildfire_rating','WNTW_RISKS':'winterweather_score','WNTW_RISKR':'winterweather_rating'})
risk_df.head()
# Out:
#    state_county_FIPS  county_FIPS county_name     state  state_FIPS  \
# 0              21115          115     Johnson  Kentucky          21
# 1              21117          117      Kenton  Kentucky          21
# 2              21119          119       Knott  Kentucky          21
# 3              21121          121        Knox  Kentucky          21
# 4              21123          123       Larue  Kentucky          21
#
#    POPULATION   BUILDVALUE  AGRIVALUE        AREA  risk_index_score  ...  \
# 0       23356   1924008000     706000  261.958144          9.281419  ...
# 1      159720  18773375000    5390000  160.213975         10.449057  ...
# 2       16346   1170376000     408000  351.517978         10.068395  ...
# 3       31883   2135773000    2534000  386.298435         11.858245  ...
# 4       14193   1221343000   41112000  261.539564          4.610900  ...
#
#   river_flooding_score  river_flooding_rating tornado_scores  \
# 0            14.575572    Relatively Moderate       9.136885
# 1             8.279166         Relatively Low      24.280149
# 2             8.755275         Relatively Low      10.174559
# 3            14.443835    Relatively Moderate      19.273345
# 4             4.055177               Very Low       9.216597
#
#         tornado_rating wildfire_scores      wildfire_rating  \
# 0       Relatively Low       13.278676       Relatively Low
# 1  Relatively Moderate        0.000000            No Rating
# 2       Relatively Low       13.363295       Relatively Low
# 3  Relatively Moderate       20.352643  Relatively Moderate
# 4       Relatively Low        0.226191             Very Low
#
#   winterweather_score  winterweather_rating SHAPE_Length  SHAPE_Area
# 0           14.131237        Relatively Low     1.553484    0.070028
# 1           12.470040        Relatively Low     1.094178    0.044207
# 2           14.466270        Relatively Low     1.694376    0.092941
# 3           19.585915   Relatively Moderate     1.920543    0.101520
# 4            7.715952              Very Low     1.830220    0.069616
#
# [5 rows x 37 columns]

# %%
# Fix state_county_FIPS so that there is a leading zero in states that have a number less then 10:
risk_df["state_county_FIPS"] = risk_df["state_county_FIPS"].astype(str)
risk_df["state_county_FIPS"] = risk_df["state_county_FIPS"].str.zfill(5)

# %%
# Combine the coastal flooding and river flooding to get an overal flood risk score:
risk_df["flood_score"] = risk_df["coastal_flooding_score"].fillna(0) + risk_df["river_flooding_score"].fillna(0)
# Change any greater than 100 to 100, that is the max score:
risk_df.loc[risk_df['flood_score'] > 100, ['flood_score']] = 100

# %% [markdown]
# ### Merge Zillow Home df and Nat'l Risk Index df:

# %%
# Merge homes_df and risk_df using a left join on the county_FIPS id var and call the merged df the home valu risk df or "hv_risk_df"- this is all county level data:
hv_risk_df = pd.merge(homes_df, risk_df, on = ["state_FIPS","county_FIPS"], how = "left")
hv_risk_df.dtypes
# Out:
# county_FIPS                  int64
# state_FIPS                   int64
# state_abbr                  object
# RegionID                     int64
# SizeRank                     int64
# home_values_Jan_2000       float64
# home_values_Dec_2021       float64
# home_values_Dec_2022       float64
# zhvi_yr_growth             float64
# state_county_FIPS           object
# county_name                 object
# state                       object
# POPULATION                   int64
# BUILDVALUE                   int64
# AGRIVALUE                    int64
# AREA                       float64
# risk_index_score           float64
# risk_index_rating           object
# exp_annual_loss_score      float64
# exp_annual_loss_rating      object
# soc_vul_score              float64
# soc_vul_rating              object
# comm_res_score             float64
# comm_res_rating             object
# coastal_flooding_score     float64
# coastal_flooding_rating     object
# drought_score              float64
# drought_rating              object
# heatwave_score             float64
# heatwave_rating             object
# hurricane_score            float64
# hurricane_rating            object
# lightning_score            float64
# lightning_rating            object
# river_flooding_score       float64
# river_flooding_rating       object
# tornado_scores             float64
# tornado_rating              object
# wildfire_scores            float64
# wildfire_rating             object
# winterweather_score        float64
# winterweather_rating        object
# SHAPE_Length               float64
# SHAPE_Area                 float64
# flood_score                float64
# dtype: object

# %% [markdown]
# - Save Merged df as .csv:

# %% [markdown]
# ## Now the US County centroids:

# %%
# County level Centroid data:
county_file = "resources/uscounties_centroid.csv"
county_df = pd.read_csv(county_file)
# county_df["county_fips"] = county_df["county_fips"].astype(str)
county_df.dtypes
# Out:
# county           object
# county_ascii     object
# county_full      object
# county_fips       int64
# state_id         object
# state_name       object
# lat             float64
# lng             float64
# population        int64
# dtype: object

# %%
# Fix state_county_FIPS so that there is a leading zero in states that have a number less then 10:
county_df["county_fips"] = county_df["county_fips"].astype(str)
county_df["county_fips"] = county_df["county_fips"].str.zfill(5)

# %%
#  Create a new df with cols we need from raw_risk_df:
# list(county_df.columns)
county_df = county_df[['county_fips','lat','lng']].copy()
county_df
# Out:
#      county_fips      lat       lng
# 0          06037  34.3209 -118.2247
# 1          17031  41.8401  -87.8168
# 2          48201  29.8578  -95.3936
# 3          04013  33.3490 -112.4915
# 4          06073  33.0343 -116.7350
# ...          ...      ...       ...
# 3138       35021  35.8579 -103.8202
# 3139       31117  41.5682 -101.0604
# 3140       48261  26.9285  -97.7017
# 3141       48269  33.6165 -100.2558
# 3142       48301  31.8493 -103.5800
#
# [3143 rows x 3 columns]

# %%
# Merge county_df and homes_df
hv_risk_county_df = pd.merge(left=hv_risk_df, right=county_df, left_on='state_county_FIPS', right_on='county_fips', how = "left")
# Drop extra county_FIPS
hv_risk_county_df = hv_risk_county_df.drop(['county_FIPS'], axis=1)
hv_risk_county_df.describe()
# Out:
#         state_FIPS     RegionID     SizeRank  home_values_Jan_2000  \
# count  2844.000000  2844.000000  2844.000000           1036.000000
# mean     30.079817  1677.743671  1439.927567         114756.305019
# std      15.249143   931.500432   844.690947          63847.204619
# min       1.000000    66.000000     0.000000          28879.000000
# 25%      18.000000   874.750000   710.750000          71779.000000
# 50%      29.000000  1673.500000  1426.500000         101169.000000
# 75%      45.000000  2487.500000  2154.250000         140001.750000
# max      56.000000  3291.000000  3132.000000         728170.000000
#
#        home_values_Dec_2021  home_values_Dec_2022  zhvi_yr_growth  \
# count          2.788000e+03          2.840000e+03     2784.000000
# mean           2.256325e+05          2.493933e+05       11.023814
# std            1.566989e+05          1.681956e+05        4.827320
# min            3.548300e+04          3.984000e+04      -14.695919
# 25%            1.324540e+05          1.463020e+05        7.790821
# 50%            1.828940e+05          2.030405e+05       10.465205
# 75%            2.718352e+05          3.023508e+05       13.885684
# max            2.224184e+06          2.332809e+06       44.260661
#
#          POPULATION    BUILDVALUE     AGRIVALUE  ...  lightning_score  \
# count  2.844000e+03  2.844000e+03  2.844000e+03  ...      2833.000000
# mean   1.079753e+05  1.239225e+10  1.193940e+08  ...        12.694223
# std    3.274150e+05  3.667292e+10  1.948116e+08  ...         8.055121
# min    6.990000e+02  1.359150e+08  0.000000e+00  ...         0.000000
# 25%    1.434575e+04  1.448479e+09  1.975175e+07  ...         7.828624
# 50%    3.000500e+04  3.177257e+09  6.138350e+07  ...        11.017877
# 75%    7.623475e+04  8.259423e+09  1.474452e+08  ...        15.230375
# max    9.818605e+06  9.509752e+11  2.938396e+09  ...       100.000000
#
#        river_flooding_score  tornado_scores  wildfire_scores  \
# count           2844.000000     2844.000000      2833.000000
# mean               9.556998       15.809881         6.374388
# std                6.876586        9.378186         8.666338
# min                0.000000        0.005204         0.000000
# 25%                5.308793        9.644649         1.465168
# 50%                8.209145       14.354040         3.184350
# 75%               11.996568       20.269387         7.831968
# max              100.000000      100.000000       100.000000
#
#        winterweather_score  SHAPE_Length   SHAPE_Area  flood_score  \
# count          2844.000000   2844.000000  2844.000000  2844.000000
# mean             13.677201      2.663493     0.263941    11.196592
# std               8.642994      2.761869     0.442150    10.551930
# min               0.000000      0.131432     0.000550     0.000000
# 25%               8.330129      1.642371     0.114593     5.522133
# 50%              12.055682      2.017602     0.161841     8.578685
# 75%              17.481956      2.706163     0.236664    12.940753
# max             100.000000     66.801075    11.197913   100.000000
#
#                lat          lng
# count  2844.000000  2844.000000
# mean     38.177569   -91.157447
# std       4.913142    12.154282
# min      19.598500  -159.596600
# 25%      34.646625   -96.585875
# 50%      38.212550   -89.129200
# 75%      41.557525   -82.937325
# max      64.807800   -67.628700
#
# [8 rows x 29 columns]

# %%
# replace all null values with 0;
hv_risk_county_df = hv_risk_county_df.replace(np.nan, 0)
hv_risk_county_df.describe()
# Out:
#         state_FIPS     RegionID     SizeRank  home_values_Jan_2000  \
# count  2844.000000  2844.000000  2844.000000           2844.000000
# mean     30.079817  1677.743671  1439.927567          41802.929677
# std      15.249143   931.500432   844.690947          67340.798768
# min       1.000000    66.000000     0.000000              0.000000
# 25%      18.000000   874.750000   710.750000              0.000000
# 50%      29.000000  1673.500000  1426.500000              0.000000
# 75%      45.000000  2487.500000  2154.250000          79102.500000
# max      56.000000  3291.000000  3132.000000         728170.000000
#
#        home_values_Dec_2021  home_values_Dec_2022  zhvi_yr_growth  \
# count          2.844000e+03          2.844000e+03     2844.000000
# mean           2.211897e+05          2.490425e+05       10.791244
# std            1.582843e+05          1.683370e+05        5.032079
# min            0.000000e+00          0.000000e+00      -14.695919
# 25%            1.296318e+05          1.462032e+05        7.602207
# 50%            1.808745e+05          2.027770e+05       10.342072
# 75%            2.692112e+05          3.022462e+05       13.810584
# max            2.224184e+06          2.332809e+06       44.260661
#
#          POPULATION    BUILDVALUE     AGRIVALUE  ...  lightning_score  \
# count  2.844000e+03  2.844000e+03  2.844000e+03  ...      2844.000000
# mean   1.079753e+05  1.239225e+10  1.193940e+08  ...        12.645124
# std    3.274150e+05  3.667292e+10  1.948116e+08  ...         8.078057
# min    6.990000e+02  1.359150e+08  0.000000e+00  ...         0.000000
# 25%    1.434575e+04  1.448479e+09  1.975175e+07  ...         7.796107
# 50%    3.000500e+04  3.177257e+09  6.138350e+07  ...        11.003673
# 75%    7.623475e+04  8.259423e+09  1.474452e+08  ...        15.186335
# max    9.818605e+06  9.509752e+11  2.938396e+09  ...       100.000000
#
#        river_flooding_score  tornado_scores  wildfire_scores  \
# count           2844.000000     2844.000000      2844.000000
# mean               9.556998       15.809881         6.349733
# std                6.876586        9.378186         8.658604
# min                0.000000        0.005204         0.000000
# 25%                5.308793        9.644649         1.437675
# 50%                8.209145       14.354040         3.166138
# 75%               11.996568       20.269387         7.764566
# max              100.000000      100.000000       100.000000
#
#        winterweather_score  SHAPE_Length   SHAPE_Area  flood_score  \
# count          2844.000000   2844.000000  2844.000000  2844.000000
# mean             13.677201      2.663493     0.263941    11.196592
# std               8.642994      2.761869     0.442150    10.551930
# min               0.000000      0.131432     0.000550     0.000000
# 25%               8.330129      1.642371     0.114593     5.522133
# 50%              12.055682      2.017602     0.161841     8.578685
# 75%              17.481956      2.706163     0.236664    12.940753
# max             100.000000     66.801075    11.197913   100.000000
#
#                lat          lng
# count  2844.000000  2844.000000
# mean     38.177569   -91.157447
# std       4.913142    12.154282
# min      19.598500  -159.596600
# 25%      34.646625   -96.585875
# 50%      38.212550   -89.129200
# 75%      41.557525   -82.937325
# max      64.807800   -67.628700
#
# [8 rows x 29 columns]

# %%
# zhvi_yr_growth to 0-100 scale:
hv_risk_county_df["zhvi_yr_growth_scale"] = ((hv_risk_county_df["zhvi_yr_growth"] - (hv_risk_county_df["zhvi_yr_growth"].min()))/ ((hv_risk_county_df["zhvi_yr_growth"].max())- (hv_risk_county_df["zhvi_yr_growth"].min())))*100
hv_risk_county_df["zhvi_yr_growth_scale"].describe()
# Out:
# count    2844.000000
# mean       43.230396
# std         8.535229
# min         0.000000
# 25%        37.821268
# 50%        42.468527
# 75%        48.351690
# max       100.000000
# Name: zhvi_yr_growth_scale, dtype: float64

# %%
hv_risk_county_df["zhvi_yr_growth_scale"].describe()
# Out:
# count    2844.000000
# mean       43.230396
# std         8.535229
# min         0.000000
# 25%        37.821268
# 50%        42.468527
# 75%        48.351690
# max       100.000000
# Name: zhvi_yr_growth_scale, dtype: float64

# %%
# Set up a var to be labels for 3 category of zhvi_yr_growth_scale:
# 696 counties would be equal to low:
# hv_risk_county_df.loc[hv_risk_county_df['zhvi_yr_growth_scale'] < 38.141188].count()

# 1392 counties would be equal to low:
# hv_risk_county_df.loc[(hv_risk_county_df['zhvi_yr_growth_scale'] > 38.141188) & (hv_risk_county_df['zhvi_yr_growth_scale'] < 48.479073)].count()

# 696 counties would be equal to low:
# hv_risk_county_df.loc[hv_risk_county_df['zhvi_yr_growth_scale'] > 48.479073].count()

hv_risk_county_df['zhvi_yr_growth_label'] = pd.qcut(hv_risk_county_df['zhvi_yr_growth_scale'], q=[0, .2, .4, .6, .8, 1], labels=['Very Low', 'Low', 'Average', 'High', 'Very High'])
hv_risk_county_df['zhvi_yr_growth_label'].value_counts()
# Out:
# Very High    569
# High         569
# Low          569
# Very Low     569
# Average      568
# Name: zhvi_yr_growth_label, dtype: int64

# %%
# Save merged df, hv_risk_df, to .csv in Output Folder and this is ready to manipulate further and save to mongoDB:
hv_risk_county_df.to_csv("output/hv_risk_df.csv", index=False)

# %% [markdown]
# # Read in Data After cleaning/merge:

# %%
# Read in happiness data from csv:
hv_risk_file = "output/hv_risk_df.csv"
hv_risk_df = pd.read_csv(hv_risk_file)
# Convert missing values NaN to "None" for use in sqlite and later converting to json:
# hv_risk_df = hv_risk_df.where(pd.notnull(hv_risk_df), None)
hv_risk_df.dtypes
# Out:
# state_FIPS                   int64
# state_abbr                  object
# RegionID                     int64
# SizeRank                     int64
# home_values_Jan_2000       float64
# home_values_Dec_2021       float64
# home_values_Dec_2022       float64
# zhvi_yr_growth             float64
# state_county_FIPS            int64
# county_name                 object
# state                       object
# POPULATION                   int64
# BUILDVALUE                   int64
# AGRIVALUE                    int64
# AREA                       float64
# risk_index_score           float64
# risk_index_rating           object
# exp_annual_loss_score      float64
# exp_annual_loss_rating      object
# soc_vul_score              float64
# soc_vul_rating              object
# comm_res_score             float64
# comm_res_rating             object
# coastal_flooding_score     float64
# coastal_flooding_rating     object
# drought_score              float64
# drought_rating              object
# heatwave_score             float64
# heatwave_rating             object
# hurricane_score            float64
# hurricane_rating            object
# lightning_score            float64
# lightning_rating            object
# river_flooding_score       float64
# river_flooding_rating       object
# tornado_scores             float64
# tornado_rating              object
# wildfire_scores            float64
# wildfire_rating             object
# winterweather_score        float64
# winterweather_rating        object
# SHAPE_Length               float64
# SHAPE_Area                 float64
# flood_score                float64
# county_fips                  int64
# lat                        float64
# lng                        float64
# zhvi_yr_growth_scale       float64
# zhvi_yr_growth_label        object
# dtype: object

# %% [markdown]
# # GeoJSON of County Boundaries:
# - Combine state and county FIPS to use later in d3.js to build map with hv_risk data and then export to MongoDB Atlas Cluster:

# %%
# Read in the geoJSON:
cnty_bound_data = gpd.read_file('output/us_county_bounds_new.json')
cnty_bound_data.dtypes
# Out:
# GEO_ID                 object
# STATE                  object
# COUNTY                 object
# NAME                   object
# LSAD                   object
# CENSUSAREA            float64
# state_county_FIPS      object
# geometry             geometry
# dtype: object

# %% [markdown]
# ________________________________
# # Saving merged hv_risk_df to sqlite db:

# %%
# Read in happiness data from csv:
hv_risk_file = "output/hv_risk_df.csv"
hv_risk_df = pd.read_csv(hv_risk_file)

# %%
# Create engine that will save the sqlite file db to the output folder in our directory:
engine = create_engine('sqlite:///output/hv_risk.sqlite')
# Save df to sqlite db as a table/class called "hv_risk_merged_data":
# hv_risk_df.to_sql('hv_risk', engine, if_exists='replace')
# Make sure to set the index as the primary key using DBrowser:

# %%
# Read back in data from table called "hv_risk":
hv_risk_data = pd.read_sql_query('SELECT * FROM hv_risk',engine)
hv_risk_data
# Out:
#       index  state_FIPS state_abbr  RegionID  SizeRank  home_values_Jan_2000  \
# 0         0           6         CA      3101         0              217219.0
# 1         1          17         IL       139         1              173902.0
# 2         2          48         TX      1090         2              115286.0
# 3         3           4         AZ      2402         3              142739.0
# 4         4           6         CA      2841         4              225274.0
# ...     ...         ...        ...       ...       ...                   ...
# 2839   2839           6         CA       828      3104                   0.0
# 2840   2840           8         CO      2345      3113                   0.0
# 2841   2841           8         CO      1933      3114                   0.0
# 2842   2842          49         UT      1648      3129                   0.0
# 2843   2843           8         CO      2518      3132                   0.0
#
#       home_values_Dec_2021  home_values_Dec_2022  zhvi_yr_growth  \
# 0                 821138.0              845596.0        2.978549
# 1                 294321.0              312317.0        6.114412
# 2                 258440.0              289591.0       12.053475
# 3                 433465.0              451699.0        4.206568
# 4                 824324.0              874095.0        6.037796
# ...                    ...                   ...             ...
# 2839              518820.0              550065.0        6.022320
# 2840              423936.0              459053.0        8.283562
# 2841              376561.0              393469.0        4.490109
# 2842              301428.0              324937.0        7.799209
# 2843              392522.0              430784.0        9.747734
#
#       state_county_FIPS  ... winterweather_score winterweather_rating  \
# 0                  6037  ...           14.518174       Relatively Low
# 1                 17031  ...           56.417423            Very High
# 2                 48201  ...           65.334621            Very High
# 3                  4013  ...            6.538783             Very Low
# 4                  6073  ...            6.900459             Very Low
# ...                 ...  ...                 ...                  ...
# 2839               6003  ...           17.890629  Relatively Moderate
# 2840               8053  ...            9.218594       Relatively Low
# 2841               8079  ...            5.005185             Very Low
# 2842              49009  ...            8.572360             Very Low
# 2843               8111  ...            3.122404             Very Low
#
#       SHAPE_Length  SHAPE_Area  flood_score  county_fips      lat       lng  \
# 0         8.493046    1.036605    23.389422         6037  34.3209 -118.2247
# 1         3.186134    0.268912    40.855248        17031  41.8401  -87.8168
# 2         3.879945    0.429804   100.000000        48201  29.8578  -95.3936
# 3         8.119691    2.314110    20.728803         4013  33.3490 -112.4915
# 4         6.453682    1.059064    20.965521         6073  33.0343 -116.7350
# ...            ...         ...          ...          ...      ...       ...
# 2839      2.174214    0.199044     0.030130         6003  38.5972 -119.8207
# 2840      2.846950    0.297671     3.489408         8053  37.8215 -107.3003
# 2841      2.045067    0.232169     5.984310         8079  37.6689 -106.9241
# 2842      2.895317    0.199419     0.123687        49009  40.8873 -109.5076
# 2843      1.716641    0.102834     0.930465         8111  37.7640 -107.6762
#
#       zhvi_yr_growth_scale zhvi_yr_growth_label
# 0                29.978789             Very Low
# 1                35.297725             Very Low
# 2                45.371346                 High
# 3                32.061709             Very Low
# 4                35.167771             Very Low
# ...                    ...                  ...
# 2839             35.141521             Very Low
# 2840             38.976957                  Low
# 2841             32.542641             Very Low
# 2842             38.155416                  Low
# 2843             41.460432              Average
#
# [2844 rows x 50 columns]

# %%
# Top three counties for home value growth scale:
top_zvhi = hv_risk_data.loc[hv_risk_data["zhvi_yr_growth_scale"]> 75].sort_values(by="zhvi_yr_growth_scale", ascending=False)

print(top_zvhi["county_name"])
print(top_zvhi["state"])
top_zvhi
# Out:
# 531        Wayne
# 2761      Kimble
# 752        Kauai
# 1106    Sullivan
# 738     Sullivan
# 859          Lee
# 916       Coffee
# Name: county_name, dtype: object
# 531               Ohio
# 2761             Texas
# 752             Hawaii
# 1106     New Hampshire
# 738           New York
# 859     North Carolina
# 916          Tennessee
# Name: state, dtype: object
#       index  state_FIPS state_abbr  RegionID  SizeRank  home_values_Jan_2000  \
# 531     531          39         OH       797       531              165017.0
# 2761   2761          48         TX      1136      2869                   0.0
# 752     752          15         HI       578       752              187454.0
# 1106   1106          33         NH      2566      1109                   0.0
# 738     738          36         NY      2567       738               76586.0
# 859     859          37         NC        86       860              105661.0
# 916     916          47         TN       947       918               95010.0
#
#       home_values_Dec_2021  home_values_Dec_2022  zhvi_yr_growth  \
# 531               299991.0              432769.0       44.260661
# 2761              235295.0              327000.0       38.974479
# 752               768926.0             1060321.0       37.896365
# 1106              240754.0              329052.0       36.675611
# 738               222146.0              293558.0       32.146426
# 859               187224.0              246192.0       31.495962
# 916               204084.0              267192.0       30.922561
#
#       state_county_FIPS  ... winterweather_score winterweather_rating  \
# 531               39169  ...           28.553387      Relatively High
# 2761              48267  ...           14.889998       Relatively Low
# 752               15007  ...            0.000000            No Rating
# 1106              33019  ...            8.847775       Relatively Low
# 738               36105  ...            9.103259       Relatively Low
# 859               37105  ...           21.089490  Relatively Moderate
# 916               47031  ...           15.295802       Relatively Low
#
#       SHAPE_Length  SHAPE_Area  flood_score  county_fips      lat       lng  \
# 531       1.603852    0.153954     9.446526        39169  40.8289  -81.8880
# 2761      2.472197    0.304449    22.770399        48267  30.4868  -99.7487
# 752       2.951880    0.141969    22.415814        15007  22.0398 -159.5966
# 1106      2.147501    0.158787     9.911053        33019  43.3614  -72.2222
# 738       2.753594    0.279299    24.497828        36105  41.7164  -74.7681
# 859       1.279412    0.066670     9.450365        37105  35.4752  -79.1715
# 916       2.008073    0.111794     6.959403        47031  35.4906  -86.0748
#
#       zhvi_yr_growth_scale zhvi_yr_growth_label
# 531             100.000000            Very High
# 2761             91.033771            Very High
# 752              89.205112            Very High
# 1106             87.134514            Very High
# 738              79.452277            Very High
# 859              78.348983            Very High
# 916              77.376402            Very High
#
# [7 rows x 50 columns]
